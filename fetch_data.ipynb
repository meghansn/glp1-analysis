# %% [markdown]
# <a href="https://colab.research.google.com/github/meghansn/glp1-analysis/blob/main/fetch_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
project_id = 'glp1-project-498216'
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# !gsutil ls
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# gs://my-pharma-data-project/

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45188144-517f-44e1-b65d-676d67904b98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45188144-517f-44e1-b65d-676d67904b98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -l kaggle.json
# Out:
# -rw-r--r-- 1 root root 73 Jun  2 17:12 kaggle.json

# %%
# 1. Create the hidden Kaggle directory
# !mkdir -p ~/.kaggle

# 2. Move your uploaded file into that hidden directory
# !cp kaggle.json ~/.kaggle/

# 3. Change permissions so it's secure (Kaggle requires this)
# !chmod 600 ~/.kaggle/kaggle.json

# 4. Install the Kaggle library
# !pip install kaggle

# %%
# 1. Download the dataset
# !kaggle datasets download -d devtayyabsajjad/glp-1-weight-loss-drugs-master-dataset-2017-2026

# 2. Unzip it
# !unzip glp-1-weight-loss-drugs-master-dataset-2017-2026.zip -d ./glp_data

# 3. Copy to your GCS bucket
# !gsutil -m cp -r ./glp_data/* gs://my-pharma-data-project/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/devtayyabsajjad/glp-1-weight-loss-drugs-master-dataset-2017-2026
# License(s): CC0-1.0
# ...
# 100% 1.79M/1.79M [00:00<00:00, 153MB/s]
#
# Archive:  glp-1-weight-loss-drugs-master-dataset-2017-2026.zip
#   inflating: ./glp_data/adverse_events.csv
#   inflating: ./glp_data/adverse_events_summary.csv
#   inflating: ./glp_data/clinical_trials.csv
#   inflating: ./glp_data/data_dictionary.csv
#   inflating: ./glp_data/drugs_overview.csv
#   inflating: ./glp_data/search_trends.csv
#   inflating: ./glp_data/stock_prices.csv
#   inflating: ./glp_data/wikipedia_summaries.csv
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying file://./glp_data/adverse_events.csv [Content-Type=text/csv]...
# ...

# %%
# 1. Download and unzip
# !wget -O canada_adverse_data.zip "https://open.canada.ca/data/dataset/9cbaef00-b52c-4a70-9fed-d9aa8263ab74/resource/2e736909-ef1f-4d60-bfb6-f15b3be3b1fa/download/extract_extrait.zip"
# !mkdir -p ./canada_data
# !unzip canada_adverse_data.zip -d ./canada_data

# 2. Upload to your bucket in a clean subfolder
# !gsutil -m cp -r ./canada_data/* gs://my-pharma-data-project/canada-adverse-data/

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Check if the folder already exists to avoid errors
# !mkdir -p ./canada_data

# Use a more verbose (detailed) copy command so we can see the progress
# Adding -v (verbose) helps you see if it's actually moving files
# !gsutil -m cp -v -r ./canada_data/* gs://my-pharma-data-project/canada-adverse-data/
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying file://./canada_data/cvponline_extract_20241130/report_type_lx.txt [Content-Type=text/plain]...
# Copying file://./canada_data/cvponline_extract_20241130/report_drug_indication.txt [Content-Type=text/plain]...
# Copying file://./canada_data/cvponline_extract_20241130/drug_products.txt [Content-Type=text/plain]...
# Copying file://./canada_data/cvponline_extract_20241130/reports.txt [Content-Type=text/plain]...
# Copying file://./canada_data/cvponline_extract_20241130/drug_product_ingredients.txt [Content-Type=text/plain]...
# Copying file://./canada_data/cvponline_extract_20241130/outcome_lx.txt [Content-Type=text/plain]...
# ...

# %%
!
# !rm kaggle.json
